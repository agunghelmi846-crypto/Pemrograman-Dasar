# %% [markdown]
# <a href="https://colab.research.google.com/github/agunghelmi846-crypto/Pemrograman-Dasar/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tegangan_panel = 18
arus_panel = 6
jenis_sel = "Monocrystalline"

print (tegangan_panel)
print (arus_panel)
print (jenis_sel)
# Out:
# 18
# 6
# Monocrystalline

# %%
jumlah_komponen = 10
tegangan = 12.5
aktif = True
nama_komponen = "Resistor"

print(jumlah_komponen, type(jumlah_komponen))
print(tegangan, type(tegangan))
print(aktif, type(aktif))
print(nama_komponen, type(nama_komponen))
# Out:
# 10 <class 'int'>
# 12.5 <class 'float'>
# True <class 'bool'>
# Resistor <class 'str'>

# %%
nama_unit = "PLTS Nunukan"
jumlah_panel = 240
tegangan_keluaran = 48.5
sedang_beroprasi = True

print(nama_unit, type(nama_unit))
print(jumlah_panel, type (jumlah_panel))
print(tegangan_keluaran, type(tegangan_keluaran))
print(sedang_beroprasi, type(sedang_beroprasi))
# Out:
# PLTS Nunukan <class 'str'>
# 240 <class 'int'>
# 48.5 <class 'float'>
# True <class 'bool'>

# %%
tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]

print(tegangan_harian[0])
print(tegangan_harian[-1])

tegangan_harian.append(222.0)

print(len(tegangan_harian))
# Out:
# 217.5
# 216.9
# 7

# %%
motor = {
    "nama": "motor induksi",
    "daya_kw": 5.5,
    "tegangan_v": 380,
    "rpm": 1450
  }

 print(motor["nama"])

  motor["rpm"] = 1500

  print(motor)
# Out:
# Motor listrik
# {'nama': 'Motor listrik', 'daya_kw': 5.5, 'tegangan_v': 380, 'rpm': 1500}

# %%
pembangkit = [
    {"nama": "unit-1", "kapasitas_mw":100, "status": "oprasi"},
    {"nama": "unit-2", "kapasitas_mw":150, "status": "oprasi"},
    {"nama": "unit-3", "kapasitas_mw":80, "status": "pemeliharaan"}
]

print(pembangkit[1]["nama"])
pembangkit[0]["status"] = "pemeliharaan"

pembangkit.append({
    "nama": "unit-4",
    "kapasitas mw": 120,
    "status": "oprasi"
    })

print(pembangkit)
# Out:
# unit-2
# [{'nama': 'unit-1', 'kapasitas_mw': 100, 'status': 'pemeliharaan'}, {'nama': 'unit-2', 'kapasitas_mw': 150, 'status': 'oprasi'}, {'nama': 'unit-3', 'kapasitas_mw': 80, 'status': 'pemeliharaan'}, {'nama': 'unit-4', 'kapasitas mw': 120, 'status': 'oprasi'}]
