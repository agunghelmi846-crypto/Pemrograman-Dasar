# %% [markdown]
# <a href="https://colab.research.google.com/github/agunghelmi846-crypto/Pemrograman-Dasar/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nama = "Helmi Agung Nugroho"
umur = 19
jurusan = "TRPE"
semester = 3
matakuliah = "Pemrograman Dasar"
status_lulus = False
hobby = "futsal"
faforite_song = "sampai jadi debu"
faforite_artist ="fiersa bersari"
faforite_club ="Manchester United"





print (nama)
print (umur)
print (jurusan)
print (semester)
print (matakuliah)
print (status_lulus)
print (hobby)
print (faforite_song)
print (faforite_artist)
print (faforite_club)
# Out:
# Helmi Agung Nugroho
# 19
# TRPE
# 3
# Pemrograman Dasar
# False
# futsal
# sampai jadi debu
# fiersa bersari
# Manchester United
